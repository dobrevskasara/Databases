-- %%
--Вашата задача ќе биде да се напишат и извршат изразите во релациона алгебра врз базата на податоци UIBK - PS Databse Systems - Exercise Sheet 5 (Pizza). 
--Оваа база на податоци содржи пет табели:
--Person(name, age, gender)       // клуч е name
--Frequents(name, pizzeria)       // клуч е [name, pizzeria]
--Eats(name, pizza)               // клуч е [name, pizza]
--Serves(pizzeria, pizza, price)  // клуч е [pizzeria, pizza]

--Оператори за изразите од релациона алгебра во ова прашање:
--Проекција - π
--Селекција - σ
--Реименување - ρ
--←
--→
--Агрегација - γ
--И - ∧
--Или - ∨
--Пресек - ∩
--Унија - ∪
--Делење - ÷
--Разлика -
--Декартов производ ⨯
--Спојување ⨝
--Спојување ⟕
--Спојување ⟖
--Спојување ⟗
--Спојување ⋉
--Спојување ⋊
--Креирање помошна релација -  име = израз

--Најди ги сите пицерии што служат пици што биле нарачани од Amy или од Fay (или од двете), а се не поевтини од $10.

-- %%
πServes.pizzeria(σPerson.name='Amy' and price>10((Person join Person.name==Eats.name (Eats)) join Eats.pizza==Serves.pizza (Serves))) ∪ 
πServes.pizzeria(σPerson.name='Fay' and price>10((Person join Person.name==Eats.name (Eats)) join Eats.pizza==Serves.pizza (Serves)))
