-- %%
--Вашата задача ќе биде да се напишат и извршат изразите во релациона алгебра врз базата на податоци UIBK - PS Databse Systems - Exercise Sheet 5 (Pizza). 
--Оваа база на податоци содржи пет табели:
--Person(name, age, gender)       // клуч е name
--Frequents(name, pizzeria)       // клуч е [name, pizzeria]
--Eats(name, pizza)               // клуч е [name, pizza]
--Serves(pizzeria, pizza, price)  // клуч е [pizzeria, pizza]

--Оператори за изразите од релациона алгебра во ова прашање:
--Проекција - π
--Селекција - σ
--Реименување - ρ
--←
--→
--Агрегација - γ
--И - ∧
--Или - ∨
--Пресек - ∩
--Унија - ∪
--Делење - ÷
--Разлика -
--Декартов производ ⨯
--Спојување ⨝
--Спојување ⟕
--Спојување ⟖
--Спојување ⟗
--Спојување ⋉
--Спојување ⋊
--Креирање помошна релација -  име = израз

--Најди ги пицериите што ги посетуваат само девојки или само момчиња.

-- %%
OnlyGirls = πpizzeria(σgender='female'(Person join Person.name==Frequents.name (Frequents)))- 
πpizzeria(σgender='male'(Person join Person.name==Frequents.name (Frequents)))

OnlyBoys = πpizzeria(σgender='male'(Person join Person.name==Frequents.name (Frequents))) - 
πpizzeria(σgender='female'(Person join Person.name==Frequents.name (Frequents)))

OnlyGirls ∪ OnlyBoys
